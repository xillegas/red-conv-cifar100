# %% [markdown]
# # Red convolucional con Cifar100
# _Por: Alfredo Villegas_
#
# En el siguiente trabajo se implementará un modelo de clasificación de imágenes utilizando una CNN en el conjunto de datos cifar 100.

# %% [markdown]
# La primera celda importa las librerías necesarias para trabajar con TensorFlow y Keras, así como las librerías Numpy y Matplotlib. Además importamos las funciones personales.

# %%
import tensorflow as tf
from keras.layers import (
    Conv2D,
    Dropout,
    MaxPooling2D,
    Flatten,
    Dense,
    BatchNormalization,
    Activation,
)
from keras import regularizers

import numpy as np

import matplotlib.pyplot as plt

import keras.datasets.cifar100 as cifar100


tf.config.list_physical_devices("GPU")
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# En esta celda, se cargan los conjuntos de datos de entrenamiento y prueba para el problema de reconocimiento de dígitos en el dataset cifar100.

# %%
(train_images, train_labels), (test_images, test_labels) = cifar100.load_data()

# %%
train_labels[4]
# Out:
# array([1])

# %% [markdown]
# Se muestra un ejemplo de una de las imágenes:

# %%
plt.figure(figsize=(10, 10))
for i in range(20):
    seed = None
    rng = np.random.default_rng(seed=seed)
    random_number = rng.integers(low=0,high=50000)
    cifar_img = plt.subplot(4, 5, i + 1)
    plt.imshow(train_images[random_number])

# %% [markdown]
# En esta celda, se llevan a cabo algunas transformaciones en los conjuntos de datos antes de ser utilizados para entrenar y probar el modelo:
#
# 1. "train_images" y "test_images" se normalizan dividiendo cada valor de píxel por 255. Esto se hace para escalar los valores de píxeles en el rango de 0 a 1, lo que facilita el procesamiento para el modelo de aprendizaje automático.
#
# 2. Luego, se modifica la forma de "train_images" y "test_images" para que sean compatibles con la entrada del modelo. Se cambia la forma de las matrices de 2D (28x28) a matrices de 3D (28x28x1), agregando una dimensión adicional que representa el número de canales de la imagen (en este caso, 1 canal porque son imágenes en escala de grises).
#
# 3. Las etiquetas de entrenamiento y prueba ("train_labels" y "test_labels") se convierten en forma de one-hot encoding utilizando la función "to_categorical" de Keras. Esto convierte las etiquetas enteras en vectores binarios de 10 dimensiones, donde cada dimensión representa una clase diferente. Esto es útil para entrenar un modelo de clasificación de múltiples clases.
#
# En resumen, estas líneas de código normalizan las imágenes, ajustan sus formas y convierten las etiquetas en one-hot encoding, preparando los datos para su posterior uso en el entrenamiento del modelo de aprendizaje automático.

# %%
train_images = train_images.astype('float32') / 255 
test_images =  test_images.astype('float32') / 255 

train_labels = tf.keras.utils.to_categorical(train_labels)
test_labels = tf.keras.utils.to_categorical(test_labels)

# %%
(train_images, valid_images) = train_images[5000:], train_images[:5000]
(train_labels, valid_labels) = train_labels[5000:], train_labels[:5000]

# %%
base_filtros = 64
w_regularizer = 1e-4
n_clases = 100
train_images.shape
# Out:
# (45000, 32, 32, 3)

# %%
train_images.shape
# Out:
# (45000, 32, 32, 3)

# %% [markdown]
# En esta celda, se define la arquitectura del modelo de red neuronal convolucional utilizando la interfaz secuencial de Keras:

# %%
model = tf.keras.Sequential()
# Conv 1
model.add(
    Conv2D(
        filters=base_filtros,
        kernel_size=(3, 3),
        padding="same",
        input_shape=train_images.shape[1:],
    )
)
model.add(Activation("relu"))
# model.add(BatchNormalization())
# - - - - - - - - - - - - - - - - - - - - -- - -
# Conv 2
model.add(Conv2D(filters=2 * base_filtros, kernel_size=(3, 3), padding="same"))
model.add(Activation("relu"))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(BatchNormalization())
model.add(Dropout(0.2))

# - - - - - - - - - - - - - - - - - - - - -- - -
# Conv 3
model.add(Conv2D(filters=4 * base_filtros, kernel_size=(3, 3), padding="same"))
model.add(Activation("relu"))
# model.add(BatchNormalization())

# - - - - - - - - - - - - - - - - - - - - -- - -
# Conv 4
model.add(Conv2D(filters=4 * base_filtros, kernel_size=(3, 3), padding="same"))
model.add(Activation("relu"))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(BatchNormalization())
model.add(Dropout(0.2))


# - - - - - - - - - - - - - - - - - - - - -- - -
# Conv 5
model.add(Conv2D(filters=8 * base_filtros, kernel_size=(3, 3), padding="same"))
model.add(Activation("relu"))
model.add(BatchNormalization())
model.add(Dropout(0.2))

# - - - - - - - - - - - - - - - - - - - - -- - -
# Conv 6
model.add(Conv2D(filters=16 * base_filtros, kernel_size=(3, 3), padding="same"))
model.add(Activation("relu"))
model.add(MaxPooling2D(pool_size=(2, 2)))
# # model.add(BatchNormalization())
# # model.add(Dropout(0.2))

# - - - - - - - - - - - - - - - - - - - - -- - -
## Clasificación - Flatten
model.add(Flatten())
model.add(Dense(1024, activation="relu"))
# model.add(Dropout(0.2))

model.add(Dense(n_clases, activation="softmax"))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 64)        1792
#
#  activation (Activation)     (None, 32, 32, 64)        0
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 128)       73856
#
#  activation_1 (Activation)   (None, 32, 32, 128)       0
#
#  max_pooling2d (MaxPooling2D  (None, 16, 16, 128)      0
#  )
#
#  batch_normalization (BatchN  (None, 16, 16, 128)      512
#  ormalization)
#
#  dropout (Dropout)           (None, 16, 16, 128)       0
#
#  conv2d_2 (Conv2D)           (None, 16, 16, 256)       295168
#
#  activation_2 (Activation)   (None, 16, 16, 256)       0
#
#  conv2d_3 (Conv2D)           (None, 16, 16, 256)       590080
#
#  activation_3 (Activation)   (None, 16, 16, 256)       0
#
#  max_pooling2d_1 (MaxPooling  (None, 8, 8, 256)        0
#  2D)
#
#  batch_normalization_1 (Batc  (None, 8, 8, 256)        1024
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 8, 8, 256)         0
#
#  conv2d_4 (Conv2D)           (None, 8, 8, 512)         1180160
#
#  activation_4 (Activation)   (None, 8, 8, 512)         0
#
#  batch_normalization_2 (Batc  (None, 8, 8, 512)        2048
#  hNormalization)
#
#  dropout_2 (Dropout)         (None, 8, 8, 512)         0
#
#  conv2d_5 (Conv2D)           (None, 8, 8, 1024)        4719616
#
#  activation_5 (Activation)   (None, 8, 8, 1024)        0
#
#  max_pooling2d_2 (MaxPooling  (None, 4, 4, 1024)       0
#  2D)
#
#  flatten (Flatten)           (None, 16384)             0
#
#  dense (Dense)               (None, 1024)              16778240
#
#  dense_1 (Dense)             (None, 100)               102500
#
# =================================================================
# Total params: 23,744,996
# Trainable params: 23,743,204
# Non-trainable params: 1,792
# _________________________________________________________________

# %% [markdown]
# Este código a continuación configura el modelo para que utilice la función de pérdida categorical_crossentropy, el optimizador rmsprop y la métrica de precisión durante el entrenamiento.

# %%
model.compile(
    loss="categorical_crossentropy", optimizer="rmsprop", metrics=["accuracy"]
)
early = tf.keras.callbacks.EarlyStopping(monitor="accuracy", patience=1)

# %% [markdown]
# Se almacena el historico del entrenamiento del modelo

# %%
with tf.device("/device:GPU:0"):
    hist = model.fit(
        train_images,
        train_labels,
        # callbacks=[early],
        validation_data=(valid_images, valid_labels),
        batch_size=32,
        epochs=10,
        verbose=1,
        shuffle=True,
    )
# Out:
# Epoch 1/10
# 1407/1407 [==============================] - 45s 29ms/step - loss: 4.9271 - accuracy: 0.1066 - val_loss: 4.0219 - val_accuracy: 0.1394
# Epoch 2/10
# 1407/1407 [==============================] - 41s 29ms/step - loss: 3.1193 - accuracy: 0.2370 - val_loss: 3.0918 - val_accuracy: 0.2590
# Epoch 3/10
# 1188/1407 [========================>.....] - ETA: 6s - loss: 2.7582 - accuracy: 0.3046
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 2
#       1 with tf.device("/device:GPU:0"):
# ----> 2     hist = model.fit(
#       3         train_images,
#       4         train_labels,
#       5         # callbacks=[early],
#       6         validation_data=(valid_images, valid_labels),
#       7         batch_size=32,
#       8         epochs=10,
#       9         verbose=1,
#      10         shuffle=True,
#      11     )
#
# File c:\ProgramData\Anaconda3\envs\tf\lib\site-packages\keras\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\ProgramData\Anaconda3\envs\tf\lib\site-packages\keras\engine\training.py:1570, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1568 logs = tmp_logs
#    1569 end_step = step + data_handler.step_increment
# -> 1570 callbacks.on_train_batch_end(end_step, logs)
#    1571 if self.stop_training:
#    1572     break
#
# File c:\ProgramData\Anaconda3\envs\tf\lib\site-packages\keras\callbacks.py:470, in CallbackList.on_train_batch_end(self, batch, logs)
#     463 """Calls the `on_train_batch_end` methods of its callbacks.
#     464
#     465 Args:
#     466     batch: Integer, index of batch within the current epoch.
#     467     logs: Dict. Aggregated metric results up until this batch.
#     468 """
#     469 if self._should_call_train_batch_hooks:
# --> 470     self._call_batch_hook(ModeKeys.TRAIN, "end", batch, logs=logs)
#
# File c:\ProgramData\Anaconda3\envs\tf\lib\site-packages\keras\callbacks.py:317, in CallbackList._call_batch_hook(self, mode, hook, batch, logs)
#     315     self._call_batch_begin_hook(mode, batch, logs)
#     316 elif hook == "end":
# --> 317     self._call_batch_end_hook(mode, batch, logs)
#     318 else:
#     319     raise ValueError(
#     320         f"Unrecognized hook: {hook}. "
#     321         'Expected values are ["begin", "end"]'
#     322     )
#
# File c:\ProgramData\Anaconda3\envs\tf\lib\site-packages\keras\callbacks.py:340, in CallbackList._call_batch_end_hook(self, mode, batch, logs)
#     337     batch_time = time.time() - self._batch_start_time
#     338     self._batch_times.append(batch_time)
# --> 340 self._call_batch_hook_helper(hook_name, batch, logs)
#     342 if len(self._batch_times) >= self._num_batches_for_timing_check:
#     343     end_hook_name = hook_name
#
# File c:\ProgramData\Anaconda3\envs\tf\lib\site-packages\keras\callbacks.py:388, in CallbackList._call_batch_hook_helper(self, hook_name, batch, logs)
#     386 for callback in self.callbacks:
#     387     hook = getattr(callback, hook_name)
# --> 388     hook(batch, logs)
#     390 if self._check_timing:
#     391     if hook_name not in self._hook_times:
#
# File c:\ProgramData\Anaconda3\envs\tf\lib\site-packages\keras\callbacks.py:1081, in ProgbarLogger.on_train_batch_end(self, batch, logs)
#    1080 def on_train_batch_end(self, batch, logs=None):
# -> 1081     self._batch_update_progbar(batch, logs)
#
# File c:\ProgramData\Anaconda3\envs\tf\lib\site-packages\keras\callbacks.py:1157, in ProgbarLogger._batch_update_progbar(self, batch, logs)
#    1153     self.seen += add_seen
#    1155 if self.verbose == 1:
#    1156     # Only block async when verbose = 1.
# -> 1157     logs = tf_utils.sync_to_numpy_or_python_type(logs)
#    1158     self.progbar.update(self.seen, list(logs.items()), finalize=False)
#
# File c:\ProgramData\Anaconda3\envs\tf\lib\site-packages\keras\utils\tf_utils.py:635, in sync_to_numpy_or_python_type(tensors)
#     632         return t
#     633     return t.item() if np.ndim(t) == 0 else t
# --> 635 return tf.nest.map_structure(_to_single_numpy_or_python_type, tensors)
#
# File c:\ProgramData\Anaconda3\envs\tf\lib\site-packages\tensorflow\python\util\nest.py:917, in map_structure(func, *structure, **kwargs)
#     913 flat_structure = (flatten(s, expand_composites) for s in structure)
#     914 entries = zip(*flat_structure)
#     916 return pack_sequence_as(
# --> 917     structure[0], [func(*x) for x in entries],
#     918     expand_composites=expand_composites)
#
# File c:\ProgramData\Anaconda3\envs\tf\lib\site-packages\tensorflow\python\util\nest.py:917, in <listcomp>(.0)
#     913 flat_structure = (flatten(s, expand_composites) for s in structure)
#     914 entries = zip(*flat_structure)
#     916 return pack_sequence_as(
# --> 917     structure[0], [func(*x) for x in entries],
#     918     expand_composites=expand_composites)
#
# File c:\ProgramData\Anaconda3\envs\tf\lib\site-packages\keras\utils\tf_utils.py:628, in sync_to_numpy_or_python_type.<locals>._to_single_numpy_or_python_type(t)
#     625 def _to_single_numpy_or_python_type(t):
#     626     # Don't turn ragged or sparse tensors to NumPy.
#     627     if isinstance(t, tf.Tensor):
# --> 628         t = t.numpy()
#     629     # Strings, ragged and sparse tensors don't have .item(). Return them
#     630     # as-is.
#     631     if not isinstance(t, (np.ndarray, np.generic)):
#
# File c:\ProgramData\Anaconda3\envs\tf\lib\site-packages\tensorflow\python\framework\ops.py:1157, in _EagerTensorBase.numpy(self)
#    1134 """Copy of the contents of this Tensor into a NumPy array or scalar.
#    1135
#    1136 Unlike NumPy arrays, Tensors are immutable, so this method has to copy
#    (...)
#    1154     NumPy dtype.
#    1155 """
#    1156 # TODO(slebedev): Consider avoiding a copy for non-CPU or remote tensors.
# -> 1157 maybe_arr = self._numpy()  # pylint: disable=protected-access
#    1158 return maybe_arr.copy() if isinstance(maybe_arr, np.ndarray) else maybe_arr
#
# File c:\ProgramData\Anaconda3\envs\tf\lib\site-packages\tensorflow\python\framework\ops.py:1123, in _EagerTensorBase._numpy(self)
#    1121 def _numpy(self):
#    1122   try:
# -> 1123     return self._numpy_internal()
#    1124   except core._NotOkStatusException as e:  # pylint: disable=protected-access
#    1125     raise core._status_to_exception(e) from None
#
# KeyboardInterrupt:

# %%
print(model.evaluate(test_images, test_labels, verbose=0)[1])
# Out:
# 0.39879998564720154

# %% [markdown]
# A continuación se expresa una gráfica del entrenamiento del modelo a lo largo de cada una de las épocas, se puede apreciar cómo la precisión va aumentando a medida que avanzan las épocas. Además, se demuestra que agregar más capas de convolución aumentando la cantidad de filtros puede conllevar un mejor aprendizaje, no obstante se aprecia que ya al agregar una tercera capa no mejora el aprendizaje de forma considerable.

# %%
plt.plot(hist.history["accuracy"], label="Train")
plt.plot(hist.history["val_accuracy"], label="Val")

plt.legend()
plt.grid()
plt.show()

# %%
model.save("./model.h5")
